# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <Dennis Maheli>

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Dennis Maheli Shavanga__
#
# Business Intelligence Developer- data analysis.

# %% [markdown]
# _I am interested in data science because it is a discipline  that you can use to find understanding  and mean._

# %% [markdown]
# ### code below is to find the total sum of the end year Budget the coming part in dollars;  food $100, drinks $200, entertainment $100

# %%
100+200+100
# Out:
# 400

# %% [markdown]
# * food
# * Drinks
# * Entertainment

# %% [markdown]
# 1. Drink
# 2. Entertainment
# 3. Food

# %% [markdown]
# ![Capture.GIF](attachment:d73fed18-82aa-4250-a1e5-71994264f4c7.GIF)
